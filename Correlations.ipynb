# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn import tree
from matplotlib import pyplot as plt
df = pd.read_csv("data/heart_failure_clinical_records_dataset.csv")
print(df)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
col = 'age'
cat = 'Age of Patient'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = 0.25372854308800313

# %%
col = 'anaemia'
cat = 'Presence of Anaemia'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = 0.0662700984602881

# %%
col = 'creatinine_phosphokinase'
cat = 'Creatinine Phosphokinase (mcg/L)'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = 0.0627281602523747

# %%
col = 'diabetes'
cat = 'Presence of Diabetes in Patient'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.0019428833442034475

# %%
col = 'ejection_fraction'
cat = 'Ejection Fraction (%)'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.26860331239406154

# %%
col = 'high_blood_pressure'
cat = 'Presence of Hypertension'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = 0.0793510576912853

# %%
col = 'platelets'
cat = 'Platelets in blood (kiloplatelets/mL)'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.049138867980374264

# %%
col = 'serum_creatinine'
cat = 'Serum Creatinine in Blood (mg/dL)'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = 0.29427756098414976

# %%
col = 'serum_sodium'
cat = 'Serum Sodium in BLood (mEq/L)'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.19520359641640145

# %%
col = 'sex'
cat = 'Sex of Patient'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.004316376319702948

# %%
col = 'smoking'
cat = 'Whether Patient Smokes'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.012623152709359492

# %%
col = 'time'
cat = 'Time Between Hearth Failure and Follow-Up'
plt.scatter(df[col],df['DEATH_EVENT'])
plt.xlabel(f'{cat}')
plt.ylabel('Death')
plt.title(f'{cat} vs Death')
plt.show
cor = df[col].corr(df['DEATH_EVENT'])
print(f'Correlation with death = {cor}')
# Out:
# Correlation with death = -0.526963779277577
